# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk

# %%
lifeExpectancy = pd.read_csv('Dataset/train.csv')

# %%
lifeExpectancy
# Out:
#         ID  TARGET_LifeExpectancy  Country  Year  Status  AdultMortality  \
# 0        1                   67.1      146  2017       0             263
# 1        2                   59.8      146  2016       0             271
# 2        3                   57.6      146  2015       0             268
# 3        4                   55.5      146  2014       0             272
# 4        5                   57.7      146  2013       0             275
# 5        6                   58.9      146  2012       0             279
# 6        7                   57.5      146  2011       0             281
# 7        8                   57.0      146  2010       0             287
# 8        9                   63.0      146  2009       0             295
# 9       10                   54.1      146  2008       0             295
# 10      11                   54.5      146  2007       0             291
# 11      12                   58.5      146  2006       0             293
# ...

# %%
X = lifeExpectancy.drop('TARGET_LifeExpectancy', axis=1)
Y = lifeExpectancy[['TARGET_LifeExpectancy']]

# %%
from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(np.array(X), np.array(Y), test_size=0.2)
print(trainX.shape)
print(testX.shape)
print(trainY.shape)
print(testY.shape)
# Out:
# (1656, 23)
# (415, 23)
# (1656, 1)
# (415, 1)

# %%
from sklearn import linear_model
linReg = linear_model.LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
polyFeat = PolynomialFeatures(degree=2, include_bias=True)
polyTrainX = polyFeat.fit_transform(trainX)
polyTestX = polyFeat.fit_transform(testX)

linReg.fit(polyTrainX, trainY)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(linReg.intercept_)
print(linReg.coef_)
# Out:
# [-44.89966621]
# [[ 9.50515976e-04  5.61243311e-04 -7.16347118e-05  2.68125482e-06
#    1.30798350e-07  1.17296285e-06  1.30580620e-05 -1.06888011e-05
#   -9.17160574e-06  8.21510340e-06 -1.26707011e-04  6.31523666e-05
#   -1.32001302e-05 -1.12915366e-05  7.65225982e-06  3.35934241e-06
#    9.01944464e-06  2.16580946e-06 -1.67113505e-03  5.66166270e-07
#    8.23786816e-07 -5.04387277e-08  2.87087882e-06  7.45665444e-07
#    1.20529839e-06  7.98215092e-06 -2.09623777e-06  1.21154599e-03
#   -2.70892564e-06 -2.20409305e-05  1.66230853e-05 -4.52679635e-06
#    2.14839703e-04 -2.62072610e-07 -2.07532595e-08 -1.79432034e-05
#   -7.56173540e-06 -1.26227910e-05  2.34321571e-04 -3.17956943e-06
#    3.48003431e-06  3.31500000e-08 -3.08741941e-12 -5.25569539e-05
#    2.29769393e-04 -1.92059359e-03  5.45944233e-04 -1.46641800e-04
#    4.10097887e-05  1.25551436e-04 -4.02377017e-06 -1.01385839e-04
#    9.33382982e-05  3.14668392e-04 -1.21492413e-03 -1.85772344e-06
# ...

# %%
predY = linReg.predict(polyTestX)

# %%
from sklearn.metrics import mean_squared_error
print('Mean squared error ', mean_squared_error(testY, predY))
# Out:
# Mean squared error  20.144692539611125

# %%
from sklearn.metrics import r2_score
score = r2_score(testY, predY)

print(score)
# Out:
# 0.7718833611986922
